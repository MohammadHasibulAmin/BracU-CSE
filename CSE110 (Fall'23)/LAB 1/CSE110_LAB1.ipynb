# %%
#task1
user_input_x = input("type in anything you want : ")
user_input_y = int(input("type a whole number : "))
print(user_input_x," : is a STRING you just typed")
print(user_input_y," : this is a whole number, or a INTEGAR datatype")
# Out:
# type in anything you want : hello world
# type a whole number : 21
# hello world  : is a STRING you just typed
# 21  : this is a whole number, or a INTEGAR datatype

# %%
#task2
user_input_x = int(input("enter the first value : "))
user_input_y = int(input("enter the second value : "))
z = user_input_x + user_input_y
q = user_input_x * user_input_y
print("the summation of the two values are : "+str(z))
print("and this is the multiplication of the two values : "+str(q))
# Out:
# enter the first value : 10
# enter the second value : 5
# the summation of the two values are : 15
# anbd this is the multiplication of the two values : 50

# %%
#task3
user_input_x = int(input("input your integar value : "))
user_input_y = float(input("input your float value :"))
z = user_input_x + (user_input_y)
q = user_input_x - user_input_y
print(z," ",q)
# Out:
# input your integar value : 4
# input your float value :5
# 9.0   -1.0

# %%
#task4
user_input_x = int(input("enter your first integar value : "))
user_input_y = int(input("enter your second integar value : "))
z = str(user_input_x) + str(float(user_input_y))
print(z)
# Out:
# 2
# 3
# 23.0

# %%
#class_task_2
user_input_x = int(input("type in your first value : "))
user_input_y = int(input("type in your second value : "))
z = user_input_x**user_input_y
print(str(user_input_x)+"^"+str(user_input_y)," : ",str(z))
# Out:
# type in your first value : 2
# type in your second value : 3
# 2^3  :  8

# %%
#class_task_3
user_input_x = int(input("enter the weight(in unit) : "))
y = user_input_x//4
z = y*4
print(z)
# Out:
# enter the weight(in unit) : 11
# 8

# %%
#class_evaluation_task_1
a = int(input("type your first value : "))
b = int(input("type your second value : "))
c = int(input("type your third value : "))
d = float(input("type your fourth value : "))
print(int(a**c + (2*b)*(a//2) - d/3))
# Out:
# type your first value : 2
# type your second value : 6
# type your third value : 8
# type your fourth value : 1.3
# 267

# %%
#class_evaluation_task_2
first_name = input("what is your first name : ")
last_name = input("what is your Last Name: ")
age = int(input(("How old are you : ")))
age -= 2
cgpa = float(input("CGPA : "))
cgpa += .25
print("Name : "+first_name+" Rahman")
print("Age : "+str(age))
print("CGPA : "+str(cgpa))
# Out:
# what is your first name : Labiba
# what is your Last Name: Ahmed
# How old are you : 23
# CGPA : 3.7
# Name : Labiba Rahman
# Age : 21
# CGPA : 3.95

# %%
#home_task_3
user_input_x = int(input("number of chocolates : "))
y = user_input_x//3
z = user_input_x - y*3
print("Each friend will receive "+str(y)+" chocolates")
print("The number of remaining chocolates is "+str(z))
# Out:
# number of chocolates : 50
# Each friend will receive 16 chocolates
# The number of remaining chocolates is 2
