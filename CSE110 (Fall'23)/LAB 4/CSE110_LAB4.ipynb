# %%
#Class_Task_1.1

user = input("type any words : ")

length = len(user)

for i in range(length-1,-1,-1):
  print(user[i],end="")
# Out:
# 011ESC

# %%
#Class_Task_1.2

user = input()
index = int(input())
quantity = len(user)

for i in range(index,-1,-1):
  print(user[i],end="")
for j in range(index+1,quantity):
  print(user[j],end="")
# Out:
# 32145

# %%
#Class_Task_2.1

user = input("type exactly one word : ")

length = len(user)

for i in range(0,length):
  print(user[i],":",ord(user[i]))
# Out:
# type exactly one word : quincuncial
# q : 113
# u : 117
# i : 105
# n : 110
# c : 99
# u : 117
# n : 110
# c : 99
# i : 105
# a : 97
# l : 108

# %%
#Class_Task_2.2

user = input("type any word: ")
quant = len(user)

for i in range(quant):
  if i != 0 and i%2 != 0:
    print(chr(ord(user[i])-32),end="")
# Out:
# type any words : string
# TIG

# %%
#Class_Task_3

user = input("")
split = ord(input())

for i in range(len(user)):
  if ord(user[i]) == split:
    print("")
  else:
    print(user[i],end="")
# Out:
# This-is-CSE110
# -
# This
# is
# CSE110

# %%
#Class_Evaluation_Task_1

user = input("")
bin = True

for i in range(len(user)):
  if ord(user[i])==48 or ord(user[i])==49:
    bin = bin
  else:
    bin = False
if bin == True:
  print("Binary Number")
else:
  print("Not a Binary Number")
# Out:
# 01101101101
# Binary Number

# %%
#Class_evaluation_Task_2

phrase = input()
quant = len(phrase)
up_phrase = phrase.upper()
vowel = "AEIOUaeiou"
v = 0
c = 0

for i in range(quant):
    if ord(up_phrase[i]) in range(65,91):
         if phrase[i] in vowel:
            v += 1

         else:
            c += 1

if v > 0 and c > 0:
    if v % 3 == 0 and c % 5 == 0:
        print("Aaarr! Me Plunder!!")

    else:
        print("Blimey! No Plunder!!")

else:
    print("Blimey! No Plunder!!")
# Out:
# Yo-ho-Ya-ho-hoo
# Aaarr! Me Plunder!!

# %%
#Home_Task_1

user = (input("type anything : "))
y = len(user)
final_word = user[0]

for i in range(1,y):
    if user[i-1] != user[i]:
        final_word = final_word+user[i]
print(final_word)
# Out:
# ABCDBECE

# %%
#Home_Task_2

input_string = input("Please enter two strings separated by a comma and a space: ")

if ", " in input_string :
  comma_index = 0

  for index in range (len(input_string)) :
    if input_string[index] == "," :
      comma_index = index

  string1 = input_string[:comma_index:]
  string2 = input_string[comma_index+2:len(input_string):]
  result_string = ""

  if len(string1) > len(string2) :
    string1_part1 = string1[:len(string2):]
    string1_part2 = string1[len(string2):len(string1):]

    for i in range (len(string2)) :
      char1 = string1_part1[i]
      char2 = string2[i]
      result_string += char1 + char2

    result_string += string1_part2

  else :
    string2_part1 = string2[:len(string1):]
    string2_part2 = string2[len(string1):len(string2):]

    for i in range (len(string1)) :
      char1 = string1[i]
      char2 = string2_part1[i]
      result_string += char1 + char2

    result_string += string2_part2

  print(result_string)

else :
  print("Error: You must input two strings separated by a comma and a space")
# Out:
# AeBfCgDh

# %%
#Home_Task_3

user = input()
new_word = ""

for i in user:
    new_word += chr(ord(i)+1)

print(new_word)
# Out:
# uif!dpx

# %%
#Home_Task_4
input_string = input("Please enter a string: ")
is_upper = True
result_string = ""

for index in range (len(input_string)) :
  ascii_value = ord(input_string[index])
  if 65 <= ascii_value <= 90 or 97 <= ascii_value <= 122 :
    if is_upper :
      if 97 <= ascii_value <= 122 :
        char = chr(ascii_value - 32)
        result_string += char
        is_upper = False
      else :
        result_string += input_string[index]
        is_upper = False
    else :
      if 65 <= ascii_value <= 90 :
        char = chr(ascii_value + 32)
        result_string += char
        is_upper = True
      else :
        result_string += input_string[index]
        is_upper = True
  else :
    result_string += input_string[index]

print(result_string)
# Out:
# I       lOvE         pYtHoN         pRoGrAmMiNg
